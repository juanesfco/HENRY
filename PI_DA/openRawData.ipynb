# %% [markdown]
# # The objective of this notebook is to open and clean the raw data

# %% [markdown]
# ## homicidios.xlsx File

# %% [markdown]
# ### `HECHOS` Sheet

# %%
import pandas as pd
df_hom = pd.read_excel('raw_data/homicidios.xlsx',sheet_name='HECHOS')
df_hom
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 0    2016-0001           1 2016-01-01  2016   1   1  04:00:00   4
# 1    2016-0002           1 2016-01-02  2016   1   2  01:15:00   1
# 2    2016-0003           1 2016-01-03  2016   1   3  07:00:00   7
# 3    2016-0004           1 2016-01-10  2016   1  10  00:00:00   0
# 4    2016-0005           1 2016-01-21  2016   1  21  05:20:00   5
# ..         ...         ...        ...   ...  ..  ..       ...  ..
# 691  2021-0093           1 2021-12-13  2021  12  13  17:10:00  17
# 692  2021-0094           1 2021-12-20  2021  12  20  01:10:00   1
# 693  2021-0095           1 2021-12-30  2021  12  30  00:43:00   0
# 694  2021-0096           1 2021-12-15  2021  12  15  10:30:00  10
# 695  2021-0097           1 2021-11-18  2021  11  18  06:10:00   6
#
#                                LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0    AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1            AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                           AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3        AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4    AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
# ..                                         ...           ...  ...     ...
# 691                          AV. RIESTRA Y MOM       AVENIDA  ...     NaN
# 692                    AU DELLEPIANE Y LACARRA     AUTOPISTA  ...     NaN
# 693                        AV. GAONA Y TERRADA       AVENIDA  ...     NaN
# 694                         AV. EVA PERON 4071       AVENIDA  ...  4071.0
# 695                    PADRE CARLOS MUJICA 709         CALLE  ...   709.0
#
#                                    Cruce  \
# 0    FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                    DE LOS CORRALES AV.
# 2                                    NaN
# 3               VILLEGAS, CONRADO, GRAL.
# 4                SAENZ PE?A, LUIS, PRES.
# ..                                   ...
# 691                                  MOM
# 692                          LACARRA AV.
# 693                              TERRADA
# 694                                  NaN
# 695                                  NaN
#
#                                  Dirección Normalizada COMUNA  \
# 0    PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...      8
# 1                 PAZ, GRAL. AV. y DE LOS CORRALES AV.      9
# 2                                  ENTRE RIOS AV. 2034      1
# 3            LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.      8
# 4              SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.      1
# ..                                                 ...    ...
# 691                                  RIESTRA AV. y MOM      7
# 692         DELLEPIANE, LUIS, TTE. GRAL. y LACARRA AV.      9
# 693                                GAONA AV. y TERRADA     11
# 694                                PERON, EVA AV. 4071      9
# 695                            PADRE CARLOS MUGICA 709      1
#
#                                    XY (CABA)         pos x         pos y  \
# 0      Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1      Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2     Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3      Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4    Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
# ..                                       ...           ...           ...
# 691   Point (102728.60090138 98186.24929177)  -58.43353773  -34.64561636
# 692    Point (99624.29795829 97569.69801131)  -58.46739825  -34.65117757
# 693   Point (99116.45492358 101045.23284826)  -58.47293407  -34.61984745
# 694    Point (99324.54463985 97676.26932409)  -58.47066794  -34.65021673
# 695  Point (107664.16647795 104708.63962087)  -58.37976155  -34.58679619
#
#       PARTICIPANTES    VICTIMA    ACUSADO
# 0         MOTO-AUTO       MOTO       AUTO
# 1    AUTO-PASAJEROS       AUTO  PASAJEROS
# 2         MOTO-AUTO       MOTO       AUTO
# 3           MOTO-SD       MOTO         SD
# 4    MOTO-PASAJEROS       MOTO  PASAJEROS
# ..              ...        ...        ...
# 691       MOTO-AUTO       MOTO       AUTO
# 692       MOTO-AUTO       MOTO       AUTO
# 693     MOTO-CARGAS       MOTO     CARGAS
# 694     AUTO-CARGAS       AUTO     CARGAS
# 695  BICICLETA-AUTO  BICICLETA       AUTO
#
# [696 rows x 21 columns]

# %% [markdown]
# #### Check for NaN

# %%
import numpy as np
df_hom.replace('SD',np.nan,inplace=True)
df_hom.replace('.',np.nan,inplace=True)

# %%
df_hom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    datetime64[ns]
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   695 non-null    object
#  7   HH                     695 non-null    float64
#  8   LUGAR_DEL_HECHO        695 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  Calle                  695 non-null    object
#  11  Altura                 129 non-null    float64
#  12  Cruce                  525 non-null    object
#  13  Dirección Normalizada  688 non-null    object
#  14  COMUNA                 696 non-null    int64
#  15  XY (CABA)              696 non-null    object
#  16  pos x                  684 non-null    object
#  17  pos y                  684 non-null    object
#  18  PARTICIPANTES          696 non-null    object
#  19  VICTIMA                687 non-null    object
#  20  ACUSADO                673 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(13)
# memory usage: 114.3+ KB

# %% [markdown]
# There is just 1 NaN in the `HORA` column, hence we are going to replace it with the average time of the whole dataset

# %%
df_hom['HORA'].fillna(pd.to_datetime(df_hom['HORA'].astype(str).str.slice(-8),format='mixed').mean().time().replace(microsecond=0),inplace=True)

# %% [markdown]
# #### Create Datetime Column

# %%
df_hom['datetime'] = pd.to_datetime(df_hom['FECHA'].astype(str).str.slice(0,10) + ' ' + df_hom['HORA'].astype(str).str.slice(-8))

# %% [markdown]
# #### Imputate `pos x` and `pos y` columns

# %%
df_hom_null = df_hom[df_hom['pos x'].isnull()]
df_hom_null
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA    HH  \
# 38   2016-0052           1 2016-04-20  2016   4  20  20:00:00  20.0
# 106  2016-0136           1 2016-10-25  2016  10  25  00:00:00   0.0
# 119  2016-0151           1 2016-11-18  2016  11  18  20:35:00  20.0
# 139  2016-0174           1 2016-12-27  2016  12  27  00:00:00   0.0
# 176  2017-0042           1 2017-04-10  2017   4  10  09:00:00   9.0
# 180  2017-0050           2 2017-04-28  2017   4  28  11:08:08  11.0
# 181  2017-0051           1 2017-05-01  2017   5   1  03:47:47   3.0
# 256  2017-0140           1 2017-11-19  2017  11  19  23:22:17  23.0
# 313  2018-0039           1 2018-04-21  2018   4  21  22:15:00  22.0
# 546  2020-0026           1 2020-05-17  2020   5  17  06:40:00   6.0
# 559  2020-0039           1 2020-09-01  2020   9   1  19:17:42  19.0
# 621  2021-0023           1 2021-03-01  2021   3   1  09:20:00   9.0
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ... Cruce  \
# 38                AUTOPISTA LUGONES PK 10000     AUTOPISTA  ...   NaN
# 106         AU BUENOS AIRES - LA PLATA KM. 4     AUTOPISTA  ...   NaN
# 119                                      NaN         CALLE  ...   NaN
# 139                     AUTOPISTA 25 DE MAYO     AUTOPISTA  ...   NaN
# 176            AV. LEOPOLDO LUGONES PKM 6900      GRAL PAZ  ...   NaN
# 180  AU PERITO MORENO Y RAMAL ENLACE AU1/AU6     AUTOPISTA  ...   NaN
# 181                       AU DELLEPIANE 2400     AUTOPISTA  ...   NaN
# 256              AU ARTURO FRONDIZI PKM 3100     AUTOPISTA  ...   NaN
# 313                 AUTOPISTA LUGONES KM 4.7     AUTOPISTA  ...   NaN
# 546             LUGONES, LEOPOLDO AV. KM 6,1     AUTOPISTA  ...   NaN
# 559                          MURGUIONDO 2700         CALLE  ...   NaN
# 621         AU BUENOS AIRES LA PLATA  KM 4,5     AUTOPISTA  ...   NaN
#
#                           Dirección Normalizada COMUNA    XY (CABA)  pos x  \
# 38                                          NaN     13  Point (. .)    NaN
# 106                                         NaN      4  Point (. .)    NaN
# 119                                         NaN      0  Point (. .)    NaN
# 139                        AUTOPISTA 25 DE MAYO      0  Point (. .)    NaN
# 176                       LUGONES, LEOPOLDO AV.     14  Point (. .)    NaN
# 180                                         NaN      9  Point (. .)    NaN
# 181                                         NaN      7  Point (. .)    NaN
# 256  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI      4  Point (. .)    NaN
# 313                                         NaN     14  Point (. .)    NaN
# 546                                         NaN     14  Point (. .)    NaN
# 559                                  MURGUIONDO      9  Point (. .)    NaN
# 621                                         NaN      4  Point (. .)    NaN
#
#     pos y     PARTICIPANTES VICTIMA      ACUSADO            datetime
# 38    NaN           MOTO-SD    MOTO          NaN 2016-04-20 20:00:00
# 106   NaN       MOTO-CARGAS    MOTO       CARGAS 2016-10-25 00:00:00
# 119   NaN         PEATON-SD  PEATON          NaN 2016-11-18 20:35:00
# 139   NaN             SD-SD     NaN          NaN 2016-12-27 00:00:00
# 176   NaN       MOTO-CARGAS    MOTO       CARGAS 2017-04-10 09:00:00
# 180   NaN       MOTO-CARGAS    MOTO       CARGAS 2017-04-28 11:08:08
# 181   NaN         AUTO-AUTO    AUTO         AUTO 2017-05-01 03:47:47
# 256   NaN    MOTO-PASAJEROS    MOTO    PASAJEROS 2017-11-19 23:22:17
# 313   NaN       PEATON-AUTO  PEATON         AUTO 2018-04-21 22:15:00
# 546   NaN  MOTO-OBJETO FIJO    MOTO  OBJETO FIJO 2020-05-17 06:40:00
# 559   NaN     PEATON-CARGAS  PEATON       CARGAS 2020-09-01 19:17:42
# 621   NaN       MOTO-CARGAS    MOTO       CARGAS 2021-03-01 09:20:00
#
# [12 rows x 22 columns]

# %% [markdown]
# ##### Try Using googlemaps API

# %%
import googlemaps
apikey = input('Enter GMaps API Key: ')
gmaps = googlemaps.Client(key=apikey)
coords = []
for d in df_hom_null['LUGAR_DEL_HECHO'].values:
    if type(d) == str:
        fd = d + ', Buenos Aires'
        r = gmaps.geocode(fd)[0]['geometry']['location']
        print(r)
        coords.append(r)
    else:
        coords.append(np.nan)
# Out:
# {'lat': -34.5484519, 'lng': -58.4385529}
# {'lat': -34.6502095, 'lng': -58.3533029}
# {'lat': -34.6281775, 'lng': -58.420338}
# {'lat': -34.5484519, 'lng': -58.4385529}
# {'lat': -34.640641, 'lng': -58.492535}
# {'lat': -34.6692536, 'lng': -58.4755674}
# {'lat': -34.6377039, 'lng': -58.3767848}
# {'lat': -34.5484519, 'lng': -58.4385529}
# {'lat': -34.5484519, 'lng': -58.4385529}
# {'lat': -34.6633372, 'lng': -58.4932331}
# {'lat': -34.6502095, 'lng': -58.3533029}

# %%
index = df_hom_null.index
for i in range(len(index)):
    if type(coords[i]) != float:
        df_hom.loc[index[i],'pos x'] = coords[i]['lng']
        df_hom.loc[index[i],'pos y'] = coords[i]['lat']

# %%
df_hom[df_hom['pos x'].isnull()]
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA    HH  \
# 119  2016-0151           1 2016-11-18  2016  11  18  20:35:00  20.0
#
#     LUGAR_DEL_HECHO TIPO_DE_CALLE  ... Cruce  Dirección Normalizada COMUNA  \
# 119             NaN         CALLE  ...   NaN                    NaN      0
#
#        XY (CABA)  pos x pos y PARTICIPANTES VICTIMA ACUSADO  \
# 119  Point (. .)    NaN   NaN     PEATON-SD  PEATON     NaN
#
#                datetime
# 119 2016-11-18 20:35:00
#
# [1 rows x 22 columns]

# %% [markdown]
# There is not much we can do to make the imputation of that row

# %% [markdown]
# #### Drop Unnecesary Colums

# %%
df_hom.drop(columns=['FECHA','AAAA','MM','DD','HORA','HH','LUGAR_DEL_HECHO','Calle','Altura','Cruce','Dirección Normalizada','XY (CABA)','PARTICIPANTES'],inplace=True)
df_hom
# Out:
#             ID  N_VICTIMAS TIPO_DE_CALLE  COMUNA         pos x         pos y  \
# 0    2016-0001           1       AVENIDA       8  -58.47533969  -34.68757022
# 1    2016-0002           1      GRAL PAZ       9  -58.50877521  -34.66977709
# 2    2016-0003           1       AVENIDA       1  -58.39040293  -34.63189362
# 3    2016-0004           1       AVENIDA       8  -58.46503904  -34.68092974
# 4    2016-0005           1       AVENIDA       1  -58.38718297  -34.62246630
# ..         ...         ...           ...     ...           ...           ...
# 691  2021-0093           1       AVENIDA       7  -58.43353773  -34.64561636
# 692  2021-0094           1     AUTOPISTA       9  -58.46739825  -34.65117757
# 693  2021-0095           1       AVENIDA      11  -58.47293407  -34.61984745
# 694  2021-0096           1       AVENIDA       9  -58.47066794  -34.65021673
# 695  2021-0097           1         CALLE       1  -58.37976155  -34.58679619
#
#        VICTIMA    ACUSADO            datetime
# 0         MOTO       AUTO 2016-01-01 04:00:00
# 1         AUTO  PASAJEROS 2016-01-02 01:15:00
# 2         MOTO       AUTO 2016-01-03 07:00:00
# 3         MOTO        NaN 2016-01-10 00:00:00
# 4         MOTO  PASAJEROS 2016-01-21 05:20:00
# ..         ...        ...                 ...
# 691       MOTO       AUTO 2021-12-13 17:10:00
# 692       MOTO       AUTO 2021-12-20 01:10:00
# 693       MOTO     CARGAS 2021-12-30 00:43:00
# 694       AUTO     CARGAS 2021-12-15 10:30:00
# 695  BICICLETA       AUTO 2021-11-18 06:10:00
#
# [696 rows x 9 columns]

# %% [markdown]
# #### Check for Duplicates

# %%
sum(df_hom.duplicated())
# Out:
# 0

# %% [markdown]
# #### Last check and save DataFrame

# %%
df_hom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             696 non-null    object
#  1   N_VICTIMAS     696 non-null    int64
#  2   TIPO_DE_CALLE  696 non-null    object
#  3   COMUNA         696 non-null    int64
#  4   pos x          695 non-null    object
#  5   pos y          695 non-null    object
#  6   VICTIMA        687 non-null    object
#  7   ACUSADO        673 non-null    object
#  8   datetime       696 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 49.1+ KB

# %%
df_hom.to_csv('data/df_homicides.csv',index=False)

# %% [markdown]
# ### `VICTIMAS` Sheet

# %%
import pandas as pd
df_vic = pd.read_excel('raw_data/homicidios.xlsx',sheet_name='VICTIMAS')
df_vic
# Out:
#       ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 0    2016-0001 2016-01-01  2016   1   1             CONDUCTOR    MOTO
# 1    2016-0002 2016-01-02  2016   1   2             CONDUCTOR    AUTO
# 2    2016-0003 2016-01-03  2016   1   3             CONDUCTOR    MOTO
# 3    2016-0004 2016-01-10  2016   1  10             CONDUCTOR    MOTO
# 4    2016-0005 2016-01-21  2016   1  21             CONDUCTOR    MOTO
# ..         ...        ...   ...  ..  ..                   ...     ...
# 712  2021-0092 2021-12-12  2021  12  12                PEATON  PEATON
# 713  2021-0093 2021-12-13  2021  12  13  PASAJERO_ACOMPAÑANTE    MOTO
# 714  2021-0094 2021-12-20  2021  12  20  PASAJERO_ACOMPAÑANTE    MOTO
# 715  2021-0095 2021-12-30  2021  12  30             CONDUCTOR    MOTO
# 716  2021-0096 2021-12-15  2021  12  15             CONDUCTOR    AUTO
#
#           SEXO EDAD  FECHA_FALLECIMIENTO
# 0    MASCULINO   19  2016-01-01 00:00:00
# 1    MASCULINO   70  2016-01-02 00:00:00
# 2    MASCULINO   30  2016-01-03 00:00:00
# 3    MASCULINO   18                   SD
# 4    MASCULINO   29  2016-02-01 00:00:00
# ..         ...  ...                  ...
# 712   FEMENINO   50  2021-12-12 00:00:00
# 713   FEMENINO   18  2021-12-18 00:00:00
# 714   FEMENINO   43  2021-12-20 00:00:00
# 715  MASCULINO   27  2022-01-02 00:00:00
# 716  MASCULINO   60  2021-12-20 00:00:00
#
# [717 rows x 10 columns]

# %% [markdown]
# #### Check for NaN

# %%
import numpy as np
df_vic.replace('SD',np.nan,inplace=True)

# %%
df_vic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_hecho             717 non-null    object
#  1   FECHA                717 non-null    datetime64[ns]
#  2   AAAA                 717 non-null    int64
#  3   MM                   717 non-null    int64
#  4   DD                   717 non-null    int64
#  5   ROL                  706 non-null    object
#  6   VICTIMA              708 non-null    object
#  7   SEXO                 711 non-null    object
#  8   EDAD                 664 non-null    float64
#  9   FECHA_FALLECIMIENTO  649 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 56.1+ KB

# %% [markdown]
# ##### Check Specifically the `VICTIMA` Column

# %%
victima_dfhom = []
for id in df_vic['ID_hecho']:
    victima_dfhom = victima_dfhom + list(df_hom[df_hom['ID']==id]['VICTIMA'].values)
len(victima_dfhom)
# Out:
# 717

# %%
ids_nocc = df_vic[df_vic['VICTIMA'].values != np.array(victima_dfhom)]['ID_hecho'].values
df_vic[df_vic['VICTIMA'].values != np.array(victima_dfhom)]
# Out:
#       ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 36   2016-0049 2016-04-17  2016   4  17                   NaN     NaN
# 77   2016-0101 2016-08-07  2016   8   7                   NaN     NaN
# 89   2016-0115 2016-09-02  2016   9   2                   NaN     NaN
# 93   2016-0119 2016-09-04  2016   9   4  PASAJERO_ACOMPAÑANTE     NaN
# 141  2016-0174 2016-12-27  2016  12  27                   NaN     NaN
# 167  2017-0029 2017-03-07  2017   3   7                   NaN     NaN
# 208  2017-0074 2017-06-04  2017   6   4                   NaN     NaN
# 221  2017-0089 2017-07-13  2017   7  13                   NaN     NaN
# 237  2017-0108 2017-09-02  2017   9   2  PASAJERO_ACOMPAÑANTE    AUTO
# 238  2017-0108 2017-09-02  2017   9   2  PASAJERO_ACOMPAÑANTE    AUTO
# 280  2017-0155 2017-12-12  2017  12  12                   NaN     NaN
# 602  2020-0063 2020-12-05  2020  12   5                PEATON  PEATON
# 603  2020-0063 2020-12-05  2020  12   5  PASAJERO_ACOMPAÑANTE    MOTO
#
#           SEXO  EDAD  FECHA_FALLECIMIENTO
# 36         NaN   NaN                  NaN
# 77   MASCULINO  67.0                  NaN
# 89   MASCULINO   NaN                  NaN
# 93    FEMENINO   NaN                  NaN
# 141        NaN   NaN                  NaN
# 167  MASCULINO  34.0  2017-03-07 00:00:00
# 208  MASCULINO  70.0  2017-06-04 00:00:00
# 221  MASCULINO  23.0                  NaN
# 237  MASCULINO  17.0  2017-09-02 00:00:00
# 238  MASCULINO  10.0  2017-09-02 00:00:00
# 280  MASCULINO  77.0                  NaN
# 602  MASCULINO  38.0  2020-12-05 00:00:00
# 603  MASCULINO  21.0  2020-12-05 00:00:00

# %%
df_hom[df_hom['ID'].isin(ids_nocc)]
# Out:
#             ID  N_VICTIMAS TIPO_DE_CALLE  COMUNA               pos x  \
# 35   2016-0049           1     AUTOPISTA       4  -58.37714647568196
# 76   2016-0101           1      GRAL PAZ       9        -58.52932872
# 88   2016-0115           1         CALLE      12        -58.48935041
# 92   2016-0119           1       AVENIDA      12        -58.49659234
# 139  2016-0174           1     AUTOPISTA       0          -58.420338
# 164  2017-0029           1         CALLE       9        -58.48501341
# 201  2017-0074           1         CALLE       9        -58.52567073
# 214  2017-0089           1         CALLE       9        -58.51514709
# 230  2017-0108           2      GRAL PAZ      12        -58.49491054
# 269  2017-0155           1       AVENIDA       7        -58.45593915
# 583  2020-0063           2         CALLE      11        -58.52783814
#
#                   pos y      VICTIMA ACUSADO            datetime
# 35   -34.63657525428238          NaN     NaN 2016-04-17 00:00:00
# 76         -34.65014993          NaN     NaN 2016-08-07 19:42:00
# 88         -34.54917673          NaN  CARGAS 2016-09-02 11:50:00
# 92         -34.56353635          NaN     NaN 2016-09-04 06:40:00
# 139          -34.628177          NaN     NaN 2016-12-27 00:00:00
# 164        -34.64742455          NaN    AUTO 2017-03-07 02:15:00
# 201        -34.63787791          NaN     NaN 2017-06-04 12:50:00
# 214        -34.64787051          NaN    AUTO 2017-07-13 12:05:00
# 230        -34.54795581  OBJETO FIJO    AUTO 2017-09-02 04:53:08
# 269        -34.62656868          NaN    MOTO 2017-12-12 21:25:41
# 583        -34.61047001  PEATON_MOTO    MOTO 2020-12-05 07:10:00

# %% [markdown]
# We can't eliminate the `VICTIMA` Column

# %% [markdown]
# #### Eliminate Unnecesary Columns

# %%
df_vic.drop(columns=['FECHA','AAAA','MM','DD'],inplace=True)

# %% [markdown]
# #### Imputate the `FECHA_FALLECIMIENTO` Column

# %% [markdown]
# Assume all the deads are at the end of the day.

# %%
df_vic['FECHA_FALLECIMIENTO'] = pd.to_datetime(df_vic['FECHA_FALLECIMIENTO'].astype(str)+' '+'23:59:59',errors='coerce')
df_vic_notna = df_vic[df_vic['FECHA_FALLECIMIENTO'].notna()]
df_vic_notna
# Out:
# /var/folders/t8/1dshmvf55gn478cb8nbc9x880000gn/T/ipykernel_23667/3284932503.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_vic['FECHA_FALLECIMIENTO'] = pd.to_datetime(df_vic['FECHA_FALLECIMIENTO'].astype(str)+' '+'23:59:59',errors='coerce')
#       ID_hecho                   ROL VICTIMA       SEXO  EDAD  \
# 0    2016-0001             CONDUCTOR    MOTO  MASCULINO  19.0
# 1    2016-0002             CONDUCTOR    AUTO  MASCULINO  70.0
# 2    2016-0003             CONDUCTOR    MOTO  MASCULINO  30.0
# 4    2016-0005             CONDUCTOR    MOTO  MASCULINO  29.0
# 5    2016-0008             CONDUCTOR    MOTO  MASCULINO  30.0
# ..         ...                   ...     ...        ...   ...
# 712  2021-0092                PEATON  PEATON   FEMENINO  50.0
# 713  2021-0093  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO  18.0
# 714  2021-0094  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO  43.0
# 715  2021-0095             CONDUCTOR    MOTO  MASCULINO  27.0
# 716  2021-0096             CONDUCTOR    AUTO  MASCULINO  60.0
#
#     FECHA_FALLECIMIENTO
# 0   2016-01-01 23:59:59
# 1   2016-01-02 23:59:59
# 2   2016-01-03 23:59:59
# 4   2016-02-01 23:59:59
# 5   2016-01-24 23:59:59
# ..                  ...
# 712 2021-12-12 23:59:59
# 713 2021-12-18 23:59:59
# 714 2021-12-20 23:59:59
# 715 2022-01-02 23:59:59
# 716 2021-12-20 23:59:59
#
# [649 rows x 6 columns]

# %%
diff = []
for i in range(len(df_vic_notna)):
    id = df_vic_notna.iloc[i,0]
    ff = df_vic_notna.iloc[i,5]
    f = df_hom[df_hom['ID']==id]['datetime'].values[0]
    diff.append(ff-f)

meanDiff = np.array(diff).mean()

# %%
df_vic_isna = df_vic[df_vic['FECHA_FALLECIMIENTO'].isna()]
index = df_vic_isna.index
for i in index:
    id = df_vic_isna.loc[i,'ID_hecho']
    f = df_hom.loc[i,'datetime']
    df_vic.loc[i,'FECHA_FALLECIMIENTO'] = f+meanDiff
df_vic
# Out:
#       ID_hecho                   ROL VICTIMA       SEXO  EDAD  \
# 0    2016-0001             CONDUCTOR    MOTO  MASCULINO  19.0
# 1    2016-0002             CONDUCTOR    AUTO  MASCULINO  70.0
# 2    2016-0003             CONDUCTOR    MOTO  MASCULINO  30.0
# 3    2016-0004             CONDUCTOR    MOTO  MASCULINO  18.0
# 4    2016-0005             CONDUCTOR    MOTO  MASCULINO  29.0
# ..         ...                   ...     ...        ...   ...
# 712  2021-0092                PEATON  PEATON   FEMENINO  50.0
# 713  2021-0093  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO  18.0
# 714  2021-0094  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO  43.0
# 715  2021-0095             CONDUCTOR    MOTO  MASCULINO  27.0
# 716  2021-0096             CONDUCTOR    AUTO  MASCULINO  60.0
#
#               FECHA_FALLECIMIENTO
# 0   2016-01-01 23:59:59.000000000
# 1   2016-01-02 23:59:59.000000000
# 2   2016-01-03 23:59:59.000000000
# 3   2016-01-11 18:59:30.600924499
# 4   2016-02-01 23:59:59.000000000
# ..                            ...
# 712 2021-12-12 23:59:59.000000000
# 713 2021-12-18 23:59:59.000000000
# 714 2021-12-20 23:59:59.000000000
# 715 2022-01-02 23:59:59.000000000
# 716 2021-12-20 23:59:59.000000000
#
# [717 rows x 6 columns]

# %% [markdown]
# #### Imputate the `EDAD` Column
#
# Use a normal distribution to imputate age such that the 95% of the generated values is within 1 standard deviation of the mean.

# %%
edadV = df_vic[df_vic['EDAD'].notna()]['EDAD'].values
edadM = edadV.mean()
edadST = edadV.std()

# %%
df_vic_edadNaN = df_vic[df_vic['EDAD'].isna()]
edadImp = np.random.normal(edadM,edadST/2,len(df_vic_edadNaN)).round()
index = df_vic_edadNaN.index
edadImp
# Out:
# array([39., 49., 52., 50., 55., 47., 45., 43., 37., 25., 36., 29., 53.,
#        37., 28., 55., 34., 31., 42., 45., 57., 46., 30., 49., 38., 37.,
#        39., 31., 31., 32., 38., 41., 42., 36., 44., 42., 44., 43., 47.,
#        46., 41., 34., 24., 39., 25., 37., 51., 45., 42., 39., 42., 38.,
#        27.])

# %%
df_vic.loc[index,'EDAD'] = edadImp
df_vic
# Out:
#       ID_hecho                   ROL VICTIMA       SEXO  EDAD  \
# 0    2016-0001             CONDUCTOR    MOTO  MASCULINO  19.0
# 1    2016-0002             CONDUCTOR    AUTO  MASCULINO  70.0
# 2    2016-0003             CONDUCTOR    MOTO  MASCULINO  30.0
# 3    2016-0004             CONDUCTOR    MOTO  MASCULINO  18.0
# 4    2016-0005             CONDUCTOR    MOTO  MASCULINO  29.0
# ..         ...                   ...     ...        ...   ...
# 712  2021-0092                PEATON  PEATON   FEMENINO  50.0
# 713  2021-0093  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO  18.0
# 714  2021-0094  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO  43.0
# 715  2021-0095             CONDUCTOR    MOTO  MASCULINO  27.0
# 716  2021-0096             CONDUCTOR    AUTO  MASCULINO  60.0
#
#               FECHA_FALLECIMIENTO
# 0   2016-01-01 23:59:59.000000000
# 1   2016-01-02 23:59:59.000000000
# 2   2016-01-03 23:59:59.000000000
# 3   2016-01-11 18:59:30.600924499
# 4   2016-02-01 23:59:59.000000000
# ..                            ...
# 712 2021-12-12 23:59:59.000000000
# 713 2021-12-18 23:59:59.000000000
# 714 2021-12-20 23:59:59.000000000
# 715 2022-01-02 23:59:59.000000000
# 716 2021-12-20 23:59:59.000000000
#
# [717 rows x 6 columns]

# %% [markdown]
# #### Final check and save dataframe

# %%
df_vic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_hecho             717 non-null    object
#  1   ROL                  706 non-null    object
#  2   VICTIMA              708 non-null    object
#  3   SEXO                 711 non-null    object
#  4   EDAD                 717 non-null    float64
#  5   FECHA_FALLECIMIENTO  717 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 33.7+ KB

# %%
df_vic.to_csv('data/df_victims.csv',index=False)
